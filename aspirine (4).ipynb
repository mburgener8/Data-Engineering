# %%
import pandas as pd
import numpy as np
import panel as pn
import matplotlib.pyplot as plt

# %%
aspirine = pd.read_excel('C:/Users/win10/OneDrive/Bureau/HES/1ère/Info/project/datasheet.xlsx')
aspirine
# Out:
#     Kalenderwoche (1 Produktion pro Woche)  limitierter Stoff (Salicylsäure)  \
# 0                                        1                         48.938080
# 1                                        2                         49.647643
# 2                                        3                         51.764876
# 3                                        4                         48.004396
# 4                                        5                         49.784994
# 5                                        6                         51.917844
# 6                                        7                         53.044408
# 7                                        8                         51.278926
# 8                                        9                         50.965696
# 9                                       10                         47.064582
# 10                                      11                         53.373873
# ...

# %%
# Extrahiere die Daten für Ausbeute (r) und Massenfraktion (w)
a = aspirine['Ausbeute %']
w = aspirine['w(Salicylsäure)']

# Erstellen Sie eine Tabelle mit den Wochennummern des Jahres
weeks = aspirine['Kalenderwoche (1 Produktion pro Woche)']

# Erstellen Sie ein neues Diagramm und zeigen Sie die Daten als Scatterplot an
plt.scatter(weeks, a) # Pour le rendement
plt.scatter(weeks, w) # Pour la fraction massique
plt.xlabel('Weeks')
plt.ylabel('w')
plt.legend(['ausbeute', 'w'])
plt.show()
